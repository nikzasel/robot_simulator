# %%
from fastai.basics import *
from fastai.gen_doc.nbdoc import *
from fastai.vision import *

# %%
def norm_y_(y):
    if y.shape[0] == 1:
        y = (y//255)
    return y

# %%
learner = load_learner('temp')

# %%
img = open_image('data/Botnar/Colored/color220.png')

# %%
learner.predict(img)[0]
# Out:
# ImageSegment (1, 240, 320)

# %%
img.show()
